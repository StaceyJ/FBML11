# %% [markdown]
# <a href="https://colab.research.google.com/github/StaceyJ/FBML11/blob/main/Alphabet_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np
np.random.seed(1001)

import os
import shutil

import IPython
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tqdm import tqdm_notebook
from sklearn.model_selection import StratifiedKFold

# %matplotlib inline
matplotlib.style.use('ggplot')

# %%
import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/Audio EDA/Wavs'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/Audio EDA/Wavs/Zot.wav
# /content/drive/MyDrive/Audio EDA/Wavs/Yuk.wav
# /content/drive/MyDrive/Audio EDA/Wavs/Zuk.wav
# /content/drive/MyDrive/Audio EDA/Wavs/Z.wav
# /content/drive/MyDrive/Audio EDA/Wavs/Y.wav
# /content/drive/MyDrive/Audio EDA/Wavs/Xuk.wav
# /content/drive/MyDrive/Audio EDA/Wavs/X_ot.wav
# /content/drive/MyDrive/Audio EDA/Wavs/X.wav

# %%
import IPython.display as ipd  # To play sound in the notebook
fname = '//content/drive/MyDrive/Audio EDA/Wavs/Zot.wav'   # Z as in Zed
ipd.Audio(fname)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# Using scipy
from scipy.io import wavfile
rate, data = wavfile.read(fname)
print("Sampling (frame) rate = ", rate)
# Out:
# Sampling (frame) rate =  44100

# %%
print("Total samples (frames) = ", data.shape)
# Out:
# Total samples (frames) =  (105984,)

# %%
print(data)
# Out:
# [0 0 0 ... 0 0 0]

# %%
plt.plot(data, '-', );
