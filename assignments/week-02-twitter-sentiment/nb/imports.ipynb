# %%
# !pip install transformers torch
# !pip install emoji==0.6.0

from transformers import pipeline

pinstall = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
# Out:
# Collecting transformers
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting torch
#   Downloading torch-1.13.0-cp310-none-macosx_10_9_x86_64.whl (137.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 110.5/137.9 MB 389.1 kB/s eta 0:01:11
# ERROR: Exception:
# Traceback (most recent call last):
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 437, in _error_catcher
#     yield
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 560, in read
#     data = self._fp_read(amt) if not fp_closed else b""
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 526, in _fp_read
#     return self._fp.read(amt) if amt is not None else self._fp.read()
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/cachecontrol/filewrapper.py", line 90, in read
#     data = self.__fp.read(amt)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/http/client.py", line 465, in read
#     s = self.fp.read(amt)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/ssl.py", line 1274, in recv_into
#     return self.read(nbytes, buffer)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/ssl.py", line 1130, in read
#     return self._sslobj.read(len, buffer)
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/cli/base_command.py", line 160, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/cli/req_command.py", line 247, in wrapper
#     return func(self, options, args)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/commands/install.py", line 400, in run
#     requirement_set = resolver.resolve(
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/resolver.py", line 92, in resolve
#     result = self._result = resolver.resolve(
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 481, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 348, in resolve
#     self._add_to_criteria(self.state.criteria, r, parent=None)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/resolvelib/resolvers.py", line 172, in _add_to_criteria
#     if not criterion.candidates:
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/resolvelib/structs.py", line 151, in __bool__
#     return bool(self._sequence)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 155, in __bool__
#     return any(self)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 143, in <genexpr>
#     return (c for c in iterator if id(c) not in self._incompatible_ids)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/found_candidates.py", line 47, in _iter_built
#     candidate = func()
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/factory.py", line 206, in _make_candidate_from_link
#     self._link_candidate_cache[link] = LinkCandidate(
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 297, in __init__
#     super().__init__(
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 162, in __init__
#     self.dist = self._prepare()
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 231, in _prepare
#     dist = self._prepare_distribution()
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/resolution/resolvelib/candidates.py", line 308, in _prepare_distribution
#     return preparer.prepare_linked_requirement(self._ireq, parallel_builds=True)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 491, in prepare_linked_requirement
#     return self._prepare_linked_requirement(req, parallel_builds)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 536, in _prepare_linked_requirement
#     local_file = unpack_url(
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 166, in unpack_url
#     file = get_http_url(
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/operations/prepare.py", line 107, in get_http_url
#     from_path, content_type = download(link, temp_dir.path)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/network/download.py", line 147, in __call__
#     for chunk in chunks:
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/cli/progress_bars.py", line 53, in _rich_progress_bar
#     for chunk in iterable:
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_internal/network/utils.py", line 63, in response_chunks
#     for chunk in response.raw.stream(
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 621, in stream
#     data = self.read(amt=amt, decode_content=decode_content)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 559, in read
#     with self._error_catcher():
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/contextlib.py", line 153, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "/Users/staceyjohnson/.conda/envs/MLE11/lib/python3.10/site-packages/pip/_vendor/urllib3/response.py", line 442, in _error_catcher
#     raise ReadTimeoutError(self._pool, None, "Read timed out.")
# pip._vendor.urllib3.exceptions.ReadTimeoutError: HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out.
# Collecting emoji==0.6.0
#   Downloading emoji-0.6.0.tar.gz (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 334.2 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-0.6.0-py3-none-any.whl size=49719 sha256=86757ec502177468210d7d64130799451446cb5af06a48967f3c11642652955b
#   Stored in directory: /Users/staceyjohnson/Library/Caches/pip/wheels/a1/9f/ad/31a6a113f4caca6760acaa0f6c879b8cb5939bfa1e87cd486d
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-0.6.0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 4
#       1 get_ipython().system('pip install transformers torch')
#       2 get_ipython().system('pip install emoji==0.6.0')
# ----> 4 from transformers import pipeline
#       6 pinstall = pipeline(model="finiteautomata/bertweet-base-sentiment-analysis")
#
# ModuleNotFoundError: No module named 'transformers'
